# %% [markdown]
# **MAESTRÍA EN INTELIGENCIA ARTIFICIAL APLICADA**
#
# **Curso: TC4029 - Ciencia y analítica de datos**
#
# Tecnológico de Monterrey
#
# Prof Grettel Barceló Alonso
#
# **Semana 5**
# Preprocesamiento de datos
#
# ---

# %% [markdown]
# *   NOMBRE: Javier Alejandro Pérez Garza
# *   MATRÍCULA: A01284386

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
#import os
#DIR = "/content/drive/MyDrive/Colab Notebooks/MNA/TC4029 - Ciencia y analítica de datos/Semana 5/Actividad5_Preprocesamiento"
#os.chdir(DIR)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
response_df = pd.read_csv('responses.csv')
response_df
# Out:
#       Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0       5.0                       3.0    2.0   1.0      2.0              2.0
# 1       4.0                       4.0    2.0   1.0      1.0              1.0
# 2       5.0                       5.0    2.0   2.0      3.0              4.0
# 3       5.0                       3.0    2.0   1.0      1.0              1.0
# 4       5.0                       3.0    4.0   3.0      2.0              4.0
# ...     ...                       ...    ...   ...      ...              ...
# 1005    5.0                       2.0    5.0   2.0      2.0              5.0
# 1006    4.0                       4.0    5.0   1.0      3.0              4.0
# 1007    4.0                       3.0    1.0   1.0      2.0              2.0
# 1008    5.0                       3.0    3.0   3.0      1.0              3.0
# 1009    5.0                       5.0    4.0   3.0      2.0              3.0
#
# ...

# %% [markdown]
# 1. Determina cuántas variables numéricas y cuántas de texto posee el conjunto de datos con el método `info()` y utiliza el método `describe()` del dataframe, para obtener el resumen de las estadísticas descriptivas. Separa el análisis según el tipo de datos (number, object).

# %%
response_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1010 entries, 0 to 1009
# Columns: 150 entries, Music to House - block of flats
# dtypes: float64(134), int64(5), object(11)
# memory usage: 1.2+ MB

# %% [markdown]
# <span style="color: #FF8C00;">_Según el método `info()` en el dataframe se encuentran 139 columnas numéricas y 11 columnas de texto._</span>

# %%
#Number
response_df.describe(include=['number']).T
# Out:
#                              count        mean        std   min    25%    50%  \
# Music                       1007.0    4.731877   0.664049   1.0    5.0    5.0
# Slow songs or fast songs    1008.0    3.328373   0.833931   1.0    3.0    3.0
# Dance                       1006.0    3.113320   1.170568   1.0    2.0    3.0
# Folk                        1005.0    2.288557   1.138916   1.0    1.0    2.0
# Country                     1005.0    2.123383   1.076136   1.0    1.0    2.0
# ...                            ...         ...        ...   ...    ...    ...
# Spending on healthy eating  1008.0    3.557540   1.093750   1.0    3.0    4.0
# Age                         1003.0   20.433699   2.828840  15.0   19.0   20.0
# Height                       990.0  173.514141  10.024505  62.0  167.0  173.0
# Weight                       990.0   66.405051  13.839561  41.0   55.0   64.0
# Number of siblings          1004.0    1.297809   1.013348   0.0    1.0    1.0
#
# ...

# %%
#Text
response_df.describe(include=['object']).T
# Out:
#                        count unique                  top freq
# Smoking                 1002      4        tried smoking  430
# Alcohol                 1005      3       social drinker  659
# Punctuality             1008      3  i am always on time  399
# Lying                   1008      4            sometimes  549
# Internet usage          1010      4      few hours a day  744
# Gender                  1004      2               female  593
# Left - right handed     1007      2         right handed  906
# Education               1009      6     secondary school  621
# Only child              1008      2                   no  754
# Village - town          1006      2                 city  707
# House - block of flats  1006      2       block of flats  595

# %% [markdown]
# 2. Clasifique la variable `Weight` según su escala de medición. En función de ello elija el gráfico a generar (histograma / barras) y fundamente su elección.

# %%
response_df['Weight'].dtypes
# Out:
# dtype('float64')

# %%
#Revisar si es discreto (True) o continuo (False)
escala = np.all(np.modf(response_df['Weight'].dropna())[0] == 0)
escala
# Out:
# np.True_

# %% [markdown]
# <span style="color: #FF8C00;">_A pesar de que variable `Weight` tiene una escala de medición cuantitativa discreta en el dataframe proporcionado, el peso en la vida real es una variable continua por lo que el gráfico a generar es un histograma a través del cual podemos observar la distribución de los datos._</span>

# %%
sns.set_theme(style="whitegrid")

sns.histplot(response_df['Weight'], bins=30, kde=True, color='blue', alpha=0.6)
plt.axvline(x=response_df['Weight'].mean(), color='green', linestyle='--', label='Media')
plt.axvline(x=response_df['Weight'].median(), color='black', linestyle='-', label='Mediana')

plt.title(f'Distribución de Weight')
plt.xlabel('Weight')
plt.ylabel('Frecuencia')
plt.legend()

# %% [markdown]
# 3. Clasifique la distribución del peso según su asimetría, justificando tu respuesta. Incluye el cálculo numérico que lo demuestra.

# %%
response_df['Weight'].skew()
# Out:
# np.float64(1.2237251927527477)

# %% [markdown]
# <span style="color: #FF8C00;">_Debido a que se tiene un valor de asimetría positivo, además de lo que se puede observar en el histograma, es posible clasificar a la variable del peso con una distribución de cola derecha._</span>

# %% [markdown]
# 4. ¿Cuántos valores faltantes tiene la variable `Weight`? ¿Qué porcentaje representa?

# %%
# Calcula el número de valores faltantes por cada columna
miss_values_count = response_df['Weight'].isna().sum()
miss_values_count = miss_values_count[miss_values_count != 0]
miss_values_count
# Out:
# array([20])

# %%
#Calcula el porcentaje de valores faltantes por cada columna
percentage =  (miss_values_count / len(response_df)) * 100
percentage
# Out:
# array([1.98019802])

# %% [markdown]
# <span style="color: #FF8C00;">_La variable `Weight` tiene 20 valores faltantes que representan el 1.98%._</span>

# %% [markdown]
# 5. ¿Tendrán los valores faltantes de `Weight` relación con alguna otra variable? Analízalo considerando las siguientes columnas:
# *   Numéricas: `Age, Number of siblings`
# *   Categóricas: `Gender, Education`
#
# Para ello deberás dividir cada columna en dos grupos: con/sin faltantes en `Weight` y utilizar métodos gráficos y la prueba t para ver si hay diferencias significativas. NO olvides incluir las conclusiones del análisis con los resultados obtenidos.
#
# **NOTA**. Puedes reutilizar las funciones `Diagnose_MV_Numerical` y `Diagnose_MV_Categorical` definidas en Hands-On-Prep_Missing_Values.zip. Revisa nuevamente cómo utilizarlas.

# %%
from scipy.stats import ttest_ind
def Diagnose_MV_Numerical(df,str_att_name,BM_MV):
    MV_labels = {True:'With Missing Values',False:'Without Missing Values'}

    labels=[]
    box_sr = pd.Series('',index = BM_MV.unique())
    for poss in BM_MV.unique():
        BM = BM_MV == poss
        box_sr[poss] = df[BM][str_att_name].dropna()
        labels.append(MV_labels[poss])

    plt.boxplot(box_sr,vert=False)
    plt.yticks([1,2],labels)
    plt.xlabel(str_att_name)
    plt.show()

    plt.figure(figsize=(10,4))

    att_range = (df[str_att_name].min(),df[str_att_name].max())

    for i,poss in enumerate(BM_MV.unique()):
        plt.subplot(1,2,i+1)
        BM = BM_MV == poss
        df[BM][str_att_name].hist()
        plt.xlim = att_range
        plt.xlabel(str_att_name)
        plt.title(MV_labels[poss])

    plt.show()

    group_1_data = df[BM_MV][str_att_name].dropna()
    group_2_data = df[~BM_MV][str_att_name].dropna()

    p_value = ttest_ind(group_1_data,group_2_data).pvalue

    print('p-value of t-test: {}'.format(p_value))

# %%
from scipy.stats import chi2_contingency
def Diagnose_MV_Categorical(df,str_att_name,BM_MV):
    MV_labels = {True:'With Missing Values',False:'Without Missing Values'}

    plt.figure(figsize=(10,4))
    for i,poss in enumerate(BM_MV.unique()):
        plt.subplot(1,2,i+1)
        BM = BM_MV == poss
        df[BM][str_att_name].value_counts().plot.bar()
        plt.title(MV_labels[poss])
    plt.show()

    contigency_table = pd.crosstab(BM_MV,df[str_att_name])
    p_value = chi2_contingency(contigency_table)[1]

    print('p-value of Chi_squared test: {}'.format(p_value))

# %%
# Crear columna que indique si hay valores faltantes en Weight
missing_df = response_df['Weight'].isna()

# %% [markdown]
# <span style="color: #FF8C00;">_Variables Numéricas._</span>

# %%
# Analizar Age
Diagnose_MV_Numerical(response_df, 'Age', missing_df)
# Out:
# p-value of t-test: 0.7258243979822129

# %%
# Analizar Number of siblings
Diagnose_MV_Numerical(response_df, 'Number of siblings', missing_df)
# Out:
# p-value of t-test: 0.8255092107556896

# %% [markdown]
# <span style="color: #FF8C00;">_Variables Categóricas._</span>

# %%
# Analizar Gender
Diagnose_MV_Categorical(response_df, 'Gender', missing_df)
# Out:
# p-value of Chi_squared test: 0.5472167199163878

# %%
# Analizar Education
Diagnose_MV_Categorical(response_df, 'Education', missing_df)
# Out:
# p-value of Chi_squared test: 0.8424822989541867

# %% [markdown]
# <span style="color: #FF8C00;">_Siendo la hipótesis nula el que las variables analizadas no tienen una relación significativa con la presencia de valores faltantes en la variable `Weight`, y la hipótesis alternativa el que las variables analizadas sí tienen una relación significativa con los valores faltantes en la variable `Weight`, el hecho de que los p-values tanto del t-test como del chi-squared test sean mayores en todos los casos al valor de p-value=0.05 indica que no se rechaza la hipótesis nula, por lo que no hay evidencia estadística de que las variables analizadas estén relacionadas con los valores faltantes en `Weight`, y de esta manera es posible asumir que los valores faltantes en `Weight` parecen distribuidos de manera aleatoria y no dependen significativamente de las otras variables analizadas._</span>

# %% [markdown]
# 6. Utiliza una medida de tendencia central para imputar los valores faltantes de `Weight`. ¿Cuál es recomendable y por qué?

# %% [markdown]
# <span style="color: #FF8C00;">_Aunque es lo más común, la media asume que la variable es normalmente distribuida. En cambio, la mediana separa a la mitad superior de la mitad inferior de un conjunto de datos, por lo que es una buena representación del centro de los datos, y a la hora de imputar es la medida de tendencia central que funciona mejor en presencia de valores atípicos._</span>

# %%
# Calcular la mediana de Weight
median_weight = response_df['Weight'].median()
median_weight
# Out:
# np.float64(64.0)

# %%
# Imputar los valores faltantes con la mediana
response_df['Weight'] = response_df['Weight'].fillna(median_weight)
response_df['Weight'].to_frame()
# Out:
#       Weight
# 0       48.0
# 1       58.0
# 2       67.0
# 3       59.0
# 4       59.0
# ...      ...
# 1005    57.0
# 1006    80.0
# 1007    75.0
# 1008    58.0
# 1009    72.0
#
# [1010 rows x 1 columns]

# %%
new_values_count = response_df['Weight'].isna().sum()
new_values_count = new_values_count[new_values_count != 0]
print(new_values_count)
# Out:
# []

# %% [markdown]
# 7. ¿Hay valores atípicos de la variable `Weight`? Confírmalo con un gráfico de boxplot. ¿Cuántos son? Almacénalos en un dataframe independiente y elimínalos del conjunto original.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=response_df['Weight'])
plt.title('Boxplot de Weight')
plt.xlabel('Weight')
plt.show()

# %%
def IQR_method(df, column_name):
    # Calcular Q1 y Q3
    Q1 = df[column_name].quantile(0.25)
    Q3 = df[column_name].quantile(0.75)
    IQR = Q3 - Q1

    # Definir límites para valores atípicos
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    return IQR, lower_bound, upper_bound

# %%
IQR_Weight, W_IQR_inf, W_IQR_sup = IQR_method(response_df, 'Weight')

#Almacenar valores atípicos
outliers_df_W = response_df[(response_df['Weight'] < W_IQR_inf) | (response_df['Weight'] > W_IQR_sup)]
outliers_df_W
# Out:
#      Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 292    5.0                       4.0    5.0   2.0      3.0              2.0
# 612    5.0                       3.0    5.0   1.0      1.0              3.0
# 715    4.0                       3.0    2.0   3.0      3.0              3.0
# 793    2.0                       3.0    3.0   1.0      2.0              3.0
# 796    3.0                       5.0    3.0   2.0      2.0              4.0
# 859    5.0                       3.0    4.0   4.0      2.0              3.0
# 885    3.0                       4.0    3.0   2.0      2.0              2.0
# 973    5.0                       3.0    2.0   5.0      5.0              4.0
# 992    4.0                       4.0    4.0   1.0      4.0              4.0
# 998    5.0                       4.0    4.0   3.0      1.0              3.0
#
#      Musical  Pop  Rock  Metal or Hardrock  ...   Age  Height  Weight  \
# ...

# %%
# Mostrar el número de valores atípicos
num_outliers_W = len(outliers_df_W)
num_outliers_W
# Out:
# 10

# %% [markdown]
# <span style="color: #FF8C00;">_Existen 10 valores atípicos de la variable `Weight`._</span>

# %%
# Eliminar valores atípicos del conjunto original
response_df = response_df[~response_df.index.isin(outliers_df_W.index)].reset_index(drop=True)
response_df
# Out:
#      Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0      5.0                       3.0    2.0   1.0      2.0              2.0
# 1      4.0                       4.0    2.0   1.0      1.0              1.0
# 2      5.0                       5.0    2.0   2.0      3.0              4.0
# 3      5.0                       3.0    2.0   1.0      1.0              1.0
# 4      5.0                       3.0    4.0   3.0      2.0              4.0
# ..     ...                       ...    ...   ...      ...              ...
# 995    5.0                       2.0    5.0   2.0      2.0              5.0
# 996    4.0                       4.0    5.0   1.0      3.0              4.0
# 997    4.0                       3.0    1.0   1.0      2.0              2.0
# 998    5.0                       3.0    3.0   3.0      1.0              3.0
# 999    5.0                       5.0    4.0   3.0      2.0              3.0
#
# ...

# %% [markdown]
# 8. Repite el mismo proceso de valores atípicos con la variable `Height`.

# %%
# Calcular la mediana de Height
median_height = response_df['Height'].median()
median_height
# Out:
# np.float64(172.0)

# %%
# Imputar los valores faltantes con la mediana
response_df['Height'] = response_df['Height'].fillna(median_height)
response_df['Height'].to_frame()
# Out:
#      Height
# 0     163.0
# 1     163.0
# 2     176.0
# 3     172.0
# 4     170.0
# ..      ...
# 995   164.0
# 996   183.0
# 997   173.0
# 998   173.0
# 999   185.0
#
# [1000 rows x 1 columns]

# %%
new_values_count = response_df['Height'].isna().sum()
new_values_count = new_values_count[new_values_count != 0]
print(new_values_count)
# Out:
# []

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=response_df['Height'])
plt.title('Boxplot de Height')
plt.xlabel('Height')
plt.show()

# %%
IQR_Height, H_IQR_inf, H_IQR_sup = IQR_method(response_df, 'Height')

#Almacenar valores atípicos
outliers_df_H = response_df[(response_df['Height'] < H_IQR_inf) | (response_df['Height'] > H_IQR_sup)]
outliers_df_H
# Out:
#      Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 97     5.0                       3.0    2.0   1.0      1.0              1.0
# 220    5.0                       3.0    4.0   3.0      3.0              4.0
# 546    5.0                       4.0    1.0   4.0      2.0              5.0
# 674    5.0                       4.0    2.0   2.0      1.0              2.0
# 794    5.0                       3.0    1.0   2.0      3.0              4.0
#
#      Musical  Pop  Rock  Metal or Hardrock  ...   Age  Height  Weight  \
# 97       1.0  2.0   1.0                1.0  ...  19.0   200.0    75.0
# 220      2.0  1.0   3.0                1.0  ...  18.0   200.0    90.0
# 546      3.0  1.0   4.0                5.0  ...  21.0   203.0    80.0
# 674      2.0  1.0   2.0                2.0  ...  20.0    62.0    55.0
# 794      5.0  2.0   4.0                5.0  ...  18.0   203.0    89.0
#
#      Number of siblings  Gender  Left - right handed                Education  \
# ...

# %%
# Mostrar el número de valores atípicos
num_outliers_H = len(outliers_df_H)
num_outliers_H
# Out:
# 5

# %% [markdown]
# <span style="color: #FF8C00;">_Existen 5 valores atípicos de la variable `Height`._</span>

# %%
# Eliminar valores atípicos del conjunto original
response_df = response_df[~response_df.index.isin(outliers_df_H.index)].reset_index(drop=True)
response_df
# Out:
#      Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0      5.0                       3.0    2.0   1.0      2.0              2.0
# 1      4.0                       4.0    2.0   1.0      1.0              1.0
# 2      5.0                       5.0    2.0   2.0      3.0              4.0
# 3      5.0                       3.0    2.0   1.0      1.0              1.0
# 4      5.0                       3.0    4.0   3.0      2.0              4.0
# ..     ...                       ...    ...   ...      ...              ...
# 990    5.0                       2.0    5.0   2.0      2.0              5.0
# 991    4.0                       4.0    5.0   1.0      3.0              4.0
# 992    4.0                       3.0    1.0   1.0      2.0              2.0
# 993    5.0                       3.0    3.0   3.0      1.0              3.0
# 994    5.0                       5.0    4.0   3.0      2.0              3.0
#
# ...

# %% [markdown]
# 9. ¿Hay encuestados que sean atípicos según su índice de masa corporal (`BMI`)? El `BMI` puede ser calculado usando la siguiente fórmula:
#
# `BMI = Weight / Height ^ 2`
#
# **NOTA**. El peso tiene que estar en kilogramos y la altura en metros, pero en el conjunto la altura se ha registrado en centímetros, por lo que deberás convertirla a metros.

# %%
#Convertir Height  de centímetros a metros
response_df['Height'] = response_df['Height'] / 100
#Calcular BMI
response_df['BMI'] = response_df['Weight'] / (response_df['Height'] ** 2)
response_df['BMI'].to_frame()
# Out:
#            BMI
# 0    18.066167
# 1    21.829952
# 2    21.629649
# 3    19.943213
# 4    20.415225
# ..         ...
# 990  21.192742
# 991  23.888441
# 992  25.059307
# 993  19.379197
# 994  21.037253
#
# [995 rows x 1 columns]

# %%
#Calcular valores atípicos de BMI
IQR_BMI, BMI_inf, BMI_sup = IQR_method(response_df, 'BMI')
outliers_df_BMI = response_df[(response_df['BMI'] < BMI_inf) | (response_df['BMI'] > BMI_sup)]
outliers_df_BMI
# Out:
#      Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 42     5.0                       5.0    2.0   2.0      2.0              3.0
# 150    5.0                       4.0    3.0   1.0      1.0              3.0
# 155    5.0                       4.0    2.0   4.0      3.0              4.0
# 354    5.0                       4.0    3.0   1.0      1.0              2.0
# 398    5.0                       3.0    2.0   1.0      3.0              1.0
# 631    5.0                       3.0    3.0   5.0      4.0              3.0
#
#      Musical  Pop  Rock  Metal or Hardrock  ...  Height  Weight  \
# 42       4.0  5.0   5.0                4.0  ...    1.70    90.0
# 150      2.0  2.0   4.0                4.0  ...    1.80   100.0
# 155      2.0  3.0   5.0                2.0  ...    1.77    97.0
# 354      2.0  2.0   4.0                4.0  ...    1.79    96.0
# 398      3.0  2.0   5.0                4.0  ...    1.70    90.0
# ...

# %%
len(outliers_df_BMI)
# Out:
# 6

# %% [markdown]
# <span style="color: #FF8C00;">_A pesar de que ya se trataron los valores atípicos de las variable `Weight` y `Height`, al calcular el `BMI` se presentan 6 casos de valores atípicos._</span>

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=response_df['BMI'])
plt.title('Boxplot de BMI')
plt.xlabel('BMI')
plt.show()

# %% [markdown]
# 10. Utiliza boxplots para visualizar la distribución del `BMI` según cada una de las variables categóricas de texto. Comenta un hallazgo que llame tu atención.

# %%
# Variables categóricas
text_vars = response_df.select_dtypes(include=['object']).columns.tolist()  # Convertir a lista

# Configurar el estilo de Seaborn
sns.set_theme(style="whitegrid")

# Crear una figura con subgráficas
n_vars = len(text_vars)
n_cols = 2  # Número de columnas
n_rows = (n_vars + n_cols - 1) // n_cols  # Calcular el número de filas

plt.figure(figsize=(14, 5 * n_rows))  # Ajustar el tamaño según el número de filas

for i, var in enumerate(text_vars):
    plt.subplot(n_rows, n_cols, i + 1)  # Crear subgráficas en dos columnas
    sns.boxplot(x=var, y='BMI', data=response_df, hue=var, palette='pastel', legend=False)
    plt.title(f'Distribución de BMI según {var}')
    plt.xlabel(var)
    plt.xticks(rotation=90)  
    plt.ylabel('BMI')

plt.tight_layout()
plt.show()

# %% [markdown]
# <span style="color: #FF8C00;">_Al hacer los boxplots para visualizar la distribución del `BMI` según las variables categóricas del texto es posible notar distribuciones muy parecidas de los datos para casi todas las variables. En primera instancia, para la variable `Gender` es posible observar una diferencia entre las distribuciones de los datos, siendo la distribución del BMI de los hombres superior al de las mujeres. Esto es posible explicarlo por la naturaleza de la complexión de los hombres y las mujeres donde el BMI de los hombres en promedio es más alto que el de las mujeres. Por otro lado, en la variable `Education` es posible observar como las personas con doctorado tienen una distribución de BMI muy superior a los otros niveles de estudio, indicando que gran parte de las personas con doctorado tienen BMIs significativamente más altos que el promedio de los otros niveles educativos y aunque tengan valores atípicos de BMI, dentro de la distribución de personas con doctorados, los valores atípicos del BMI entran dentro de la distribución de los datos, aumentando la mediana de 21 en la distribución del BMI de todos los encuestados a más de 30 en las personas con el doctorado completo._</span>
